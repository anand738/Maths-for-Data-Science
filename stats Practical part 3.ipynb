# %% [markdown]
# Z-test
#
# t-test
#
# chi-squre test
#
# # take it as a assignment
# anova

# %%
import numpy as np
import scipy.stats as stats

# %%
sample_mean=110
population_mean=100
population_std=15
sample_size=50
alpha=0.05

# %%
confidence_interval=1-0.05

# %%
confidence_interval
# Out:
# 0.95

# %%
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(50))

# %%
print(z_score)
# Out:
# 4.714045207910317

# %%
import scipy.stats as stats
z_crictical = stats.norm.ppf(confidence_interval)

# %%
print(z_crictical)
# Out:
# 1.6448536269514722

# %%
if z_score>z_crictical:
    print("reject the null hyphothesis")
else:
    print("fail to reject the null hyphothesis")
# Out:
# reject the null hyphothesis

# %%
p_value=1-0.9999966

# %%
if p_value<alpha:
    print("reject the null hyphothesis")
    
else:
    print("fail to reject the null hyphothesis")
# Out:
# reject the null hyphothesis

# %%
from numpy.random import randn
mydata=randn(500)

# %%
print(mydata)
# Out:
# [ 1.44722783e-01  8.17155781e-01 -1.07890770e+00  1.27884872e-01
#   6.38066454e-01 -4.40369070e-02  2.06961343e-01  7.95585299e-01
#  -5.72488256e-01  1.30759016e-01  6.42957681e-01  7.68669770e-01
#   4.68108178e-01  1.29558405e+00  8.54488828e-01 -3.15960684e-01
#   4.82351088e-01  6.57134745e-02  3.00396140e-01 -1.56763380e+00
#  -8.28876877e-01 -1.40237796e-01 -1.12070921e+00  7.21116127e-01
#  -1.64880075e-01  6.32712810e-01  1.13337393e+00 -1.68922167e+00
#   9.87513778e-01 -1.51479459e-01  2.15000597e+00 -2.26359572e-01
#   1.22440859e+00 -3.75928276e-01  7.46363025e-01  1.71432041e-02
#   5.22811380e-01  1.20924643e+00  2.96279006e-02 -1.13659989e+00
#   4.19080718e-01 -1.46870318e+00  1.49985354e+00  1.01021738e-01
#   1.76134233e+00 -7.09472196e-01  3.40638382e-01 -1.44897740e-01
#   5.84687118e-01  2.62584425e-01  3.29654922e-02 -5.26646302e-01
#  -9.78967209e-01 -7.52027127e-01  3.10334240e-01 -8.14268519e-01
#   1.41053509e+00  4.79976293e-01  2.53179469e-01 -9.31198770e-01
#  -3.67979276e-01 -2.55790453e-02  1.95978949e-01 -5.82760065e-01
#   1.68300778e+00  2.18404080e-01 -8.53473498e-01  2.75602042e-01
#   2.79311589e-01 -1.61576383e+00  2.14098542e+00 -1.41713651e+00
#  -5.69861662e-01 -2.94626761e-01 -3.99193213e-01 -1.60979891e+00
#   1.11838495e+00 -8.63191143e-01  2.68267147e-01 -1.42360648e+00
#   3.84237546e-01  6.13286601e-01 -6.72531163e-02 -1.99631971e+00
#  -3.92850216e-01  7.95609300e-01 -1.13484434e+00  2.15770159e+00
#  -5.68226274e-01  7.77438367e-01 -4.52552758e-01  2.39144076e-01
#  -6.78060425e-02 -5.87068252e-01 -2.63967743e-03 -5.25895851e-01
#  -8.12724226e-01  8.24438914e-01  4.81305673e-01  9.95432670e-01
#   2.76821494e-01 -2.05867840e-01  1.21858546e+00  1.01980784e+00
#   1.97271831e+00 -1.53777625e+00 -8.40539956e-01  3.99350412e-01
#   4.65046826e-01 -5.09868126e-01 -3.00294026e-01  1.50109791e+00
#  -6.20990398e-01  1.80864513e+00 -1.22341950e+00 -2.63883234e+00
#  -5.20134739e-01 -1.20340845e+00  1.83049143e+00 -1.67586490e+00
#   7.49526517e-01 -1.21000674e+00  6.57709703e-01 -2.44509344e-02
#   2.01128635e-01 -2.46734654e-01 -1.62741743e-01 -8.84993862e-01
#  -4.95627421e-02 -2.24443980e-01 -1.67270594e-01  2.25720867e-02
#   4.22498414e-01 -1.68921130e+00 -9.37994617e-01 -1.00775796e+00
#  -4.91351146e-01  1.27781068e+00 -3.04317795e-02 -9.58093744e-02
#  -1.15286339e+00 -3.42447276e-01 -2.24039481e+00  8.94015594e-01
#  -1.90298712e-02  3.08641833e-01  5.52635803e-01 -1.24678068e+00
#  -6.49531735e-01  5.04291824e-01 -1.55824277e-01 -6.27079843e-01
#  -2.66838177e+00  4.71137335e-01 -8.82981212e-01  2.35949513e+00
#   9.14525793e-01  1.42563811e+00 -6.81636342e-01 -1.03793390e+00
#  -2.33755584e+00  8.37213496e-01 -2.80702362e-01  6.42874163e-01
#   1.38584851e+00 -1.92470212e+00 -3.39339415e-01  5.96956565e-01]

# %%
import seaborn as sns

# %%
sns.distplot(mydata)
# Out:
# C:\Users\agupta31\AppData\Local\Temp\ipykernel_17296\2553040580.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata)
# <Axes: ylabel='Density'>

# %%
from scipy import stats
stats.normaltest(mydata)
# Out:
# NormaltestResult(statistic=np.float64(1.4527555531311607), pvalue=np.float64(0.48365773739205686))

# %%
alpha=0.05
CI=0.95

# %%
sample_mean_iq=110
mean_population=100
population_std=15

# %%
population_std*randn(50)+sample_mean_iq
# Out:
# array([118.36271715, 110.76042903, 129.19456149, 102.39915255,
#        106.67042456, 108.80154885, 138.21113793, 107.15136754,
#        125.22853083, 138.40204074, 134.60930237, 116.61751301,
#        100.69733729, 126.2061186 , 133.27825154, 113.25671181,
#        125.95468101,  80.96784069, 107.3957785 , 112.99345792,
#        125.688102  , 119.51945035,  93.72057433, 101.93653622,
#        109.24397499, 117.35536637, 114.35816928, 132.53064058,
#         91.5485017 ,  94.25938263, 126.12190927, 106.9966185 ,
#         83.42856883, 130.46378471,  96.70575371, 115.19040508,
#         83.56115121, 125.24796182, 136.68442779, 115.69002942,
#        117.78555726,  78.11773687,  95.36271529, 122.18383724,
#        103.39216566, 146.1625948 , 111.19733647,  98.82168407,
#        116.58659229, 133.01270498])

# %%
data=population_std*randn(50)+sample_mean_iq

# %%
data
# Out:
# array([117.05622177, 101.75317106,  81.79217073, 119.79132462,
#        104.31174322, 132.56762878,  96.14888207,  76.78410852,
#        110.92328905, 110.6622582 , 101.86738542, 115.37770718,
#        101.44633518, 123.93302595,  90.22487676, 125.84749516,
#         96.86092414, 124.03246059,  99.40738989, 115.30556919,
#        103.48972526, 132.96020684, 114.40019867, 135.04928675,
#        105.89262385, 103.18591141,  99.38253732, 102.13175177,
#        125.35821585, 106.8474849 , 118.30107241, 113.58079224,
#         84.63013667, 125.20193365,  91.60850587,  83.62553859,
#         81.0835868 , 117.57157717,  99.3074987 , 126.99353566,
#        116.82983609, 123.50091691, 126.51029461, 111.41786572,
#        106.41439003, 117.5790708 ,  96.237958  , 104.94310909,
#        115.8458081 , 111.13660372])

# %%
np.mean(data)
# Out:
# np.float64(108.94223881893885)

# %%
np.std(data)
# Out:
# np.float64(14.224808635084825)

# %%
null_hyphothesis=mean_population

# %%
from statsmodels.stats.weightstats import ztest
ztest(data,value=null_hyphothesis,alternative="larger")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from statsmodels.stats.weightstats import ztest
#       2 ztest(data,value=null_hyphothesis,alternative="larger")
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
if p_value<alpha:
    print("reject the null hyphothesis")
    
else:
    print("fail to reject the null hyphothesis")

# %%
# one-sample t test(with respect to one independent sample)
# two- sample t test(with respect to two independent sample)
# paried t-test(two sample from the same populatoin on a different time interval)

# %%
my_cricket_score=[22,38,19,15,48,11,10,49,47,38,10,25,46,10,21,24,29,36,25,25]

# %%
len(my_cricket_score)
# Out:
# 20

# %%
np.mean(my_cricket_score)
# Out:
# np.float64(27.4)

# %%
sample_mean=27.4

# %%
# null_hyphothesis=>>population mean/true=sample mean

# %%
import scipy
result=scipy.stats.ttest_1samp(my_cricket_score,15)

# %%
print(result)
# Out:
# TtestResult(statistic=np.float64(4.131642363779888), pvalue=np.float64(0.0005672503150661017), df=np.int64(19))

# %%
p_value=result[1]

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")

else:
    print("accept the null hyphthesis")
# Out:
# reject the null hyphothesis

# %%
scipy.stats.ttest_1samp(my_cricket_score,27.4)
# Out:
# Ttest_1sampResult(statistic=0.0, pvalue=1.0)

# %%
p_value=scipy.stats.ttest_1samp(my_cricket_score,26)[1]

# %%
p_value
# Out:
# 0.6461790490703262

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")

else:
    print("accept the null hyphthesis")
# Out:
# accept the null hyphthesis

# %%
#two-sample t test(with respect to two independent sample)
my_cricket_score=[22, 38, 29, 45, 48, 41, 40, 49, 47, 38, 20, 45, 46, 50, 21, 44, 29,36, 25, 24]

virat_cricket_score=[33, 45, 23, 25, 46, 46, 46, 49, 49, 44, 44, 49, 25, 31, 25, 40, 30,20, 42, 37]

# %%
first_sample_mean=np.mean(my_cricket_score)

# %%
first_sample_mean
# Out:
# 36.85

# %%
second_sample_mean=np.mean(virat_cricket_score)

# %%
second_sample_mean
# Out:
# 37.45

# %%
# my_null_hyphthesis=both sample mean will be equal

# %%
t_stats,pvalue=scipy.stats.ttest_ind(my_cricket_score,virat_cricket_score)

# %%
pvalue
# Out:
# 0.852719896255562

# %%
if pvalue<=0.05:
    print("reject the null hyphothesis")
else:
    print("Accept the null hyphothesis")
# Out:
# Accept the null hyphothesis

# %%
import random
population=[]
for i in range(1,51):
    population.append(random.randint(10,80))

# %%
len(population)
# Out:
# 50

# %%
my_cricket_score_from_first_inning=np.random.choice(population,size=20)

# %%
my_cricket_score_from_second_inning=np.random.choice(population,size=20)

# %%
# paired sample t test
# take a sample from sample population on different time interval

print(my_cricket_score_from_first_inning)
print(my_cricket_score_from_second_inning)
# Out:
# [38 75 24 29 77 12 46 29 78 46 19 31 46 24 74 10 13 42 75 78]
# [59 30 13 46 51 77 10 79 19 50 12 60 19 30 75 30 71 57 12 13]

# %%
my_cricket_score_from_first_inning=[8,7,14,9,17,12,46,29,8,26,19,31,46,24,44,10,13,42,25,28]

# %%
np.mean(my_cricket_score_from_first_inning)
# Out:
# 22.9

# %%
np.mean(my_cricket_score_from_second_inning)
# Out:
# 40.65

# %%
#my_null_hyphthesis=both sample mean will be equal

# %%
t_stats,p_value=scipy.stats.ttest_rel(my_cricket_score_from_first_inning,my_cricket_score_from_second_inning)

# %%
p_value
# Out:
# 0.010973584928873221

# %%
if p_value<=0.05:
    print("reject the null hyphothesis")
else:
    print("Accept the null hyphothesis")
# Out:
# reject the null hyphothesis

# %% [markdown]
# # The weights of 25 obese people were taken before enrolling them into the nutrition camp. The population mean weight is found to be 45 kg before starting the camp. After finishing the camp, for the same 25 people, the sample mean was found to be 75 with a standard deviation of 25. Did the fitness camp work?

# %%
# h0===> mu=45(sample mean is a true/population mean)

# %%
# h1===> mu != 45 (two tail test)(sample mean is not a true/populatin mean)

# %%
n=25
populaiton_mean=45
sample_mean=75
sample_std=25
import numpy as np

# %%
t_stats=(sample_mean-populaiton_mean)/(sample_std/np.sqrt(n))

# %%
t_stats
# Out:
# np.float64(6.0)

# %%
sample_mean-populaiton_mean
# Out:
# 30

# %%
df=n-1

# %%
df
# Out:
# 24

# %%
alpha=0.05

# %%
CI=0.95

# %%
from scipy import stats
critical_value=stats.t.ppf(CI,df)

# %%
critical_value
# Out:
# np.float64(1.7108820799094275)

# %%
print("t-stats",t_stats)
print("crtical value",critical_value)
# Out:
# t-stats 6.0
# crtical value 1.7108820799094275

# %%
p_value=1-stats.t.cdf(t_stats,df)

# %%
import seaborn as sns
dataset=sns.load_dataset('tips')

# %%
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# this chi squre test we peform on top of thge categorical data

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset[["sex","smoker"]]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
import pandas as pd
dataset_table=pd.crosstab(dataset["sex"],dataset["smoker"])

# %%
dataset_table
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
dataset_array=dataset_table.values

# %%
observed_value=dataset_array

# %%
import scipy.stats as stats

# %%
stats_test,p,dof,Expected_Value=stats.chi2_contingency(dataset_array)

# %%
Expected_Value
# Out:
# array([[59.84016393, 97.15983607],
#        [33.15983607, 53.84016393]])

# %%
no_of_col=dataset_table.iloc[0:2,0]

# %%
len(no_of_col)
# Out:
# 2

# %%
no_of_row=dataset_table.iloc[0,0:2]

# %%
len(no_of_row)
# Out:
# 2

# %%
dof=(len(no_of_col)-1)*(len(no_of_row)-1)

# %%
dof
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for o,e in zip(observed_value,Expected_Value):
       print(o,e)
# Out:
# [60 97] [59.84016393 97.15983607]
# [33 54] [33.15983607 53.84016393]

# %%
from scipy.stats import chi2
chisqure=sum([(o-e)**2/e for o,e in zip(observed_value,Expected_Value)])

# %%
chisqure
# Out:
# array([0.00119737, 0.00073745])

# %%
chisqurestats=chisqure[0]+chisqure[1]

# %%
chisqurestats
# Out:
# 0.001934818536627623

# %%
alpha=0.5
Ci=0.95

# %%
critical_chi_value=chi2.ppf(Ci,df=dof)

# %%
critical_chi_value
# Out:
# 3.841458820694124

# %%
if chisqurestats>=critical_chi_value:
    print(" reject the null hyphothesis, there is a relatiuonship between two categorical variable")
else:
    print("accept the null hyphothesis there is no relation between two categorical variable")
# Out:
# accept the null hyphothesis there is no relation between two categorical variable
